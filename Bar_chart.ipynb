# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
items= ["Burger","Pizza","Pasta","Sandwich","Fries"]
sales=[120,150,90,80,110]

# %%
plt.bar(items, sales)
plt.figure(figsize=(3,3))

plt.title("Sales of Food Items")
plt.xlabel("Items")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')
