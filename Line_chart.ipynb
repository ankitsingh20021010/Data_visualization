# %%
import matplotlib.pyplot as plt

# %%
day=[1,2,3,4,5,6,7]
Temp=[32,33,34,33,32,35,34]

# %%
plt.figure(figsize=(5,5))
plt.plot(day,Temp)
plt.title("Temperature")
plt.xlabel("Day")
plt.ylabel("Temp")
plt.ylim(30, 40)#y axis limit (ylim)
# Out:
# (30.0, 40.0)
