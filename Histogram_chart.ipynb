# %%
import matplotlib.pyplot as plt

# %%
data = [22, 25, 23, 24, 26, 28, 30, 32, 35, 35, 36, 38, 40]

# %%
plt.hist(data)

# Title and labels
plt.title("Simple Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
